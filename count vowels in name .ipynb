# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaishnavi8105/neural-network-lab/blob/main/count%20vowels%20in%20name%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# count vowels in name and print
name = input("Enter your name: ")

vowels = "aeiouAEIOU"
count = 0

for letter in name:
    if letter in vowels:
        count += 1

print("Number of vowels in", name, "is:", count)
# Out:
# Enter your name: vaishnvai
# Number of vowels in vaishnvai is: 4
