# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaishnavi8105/neural-network-lab/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Import libraries
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
from sklearn.preprocessing import MinMaxScaler

# Step 2: Create sample sequential dataset
data = np.array([[10], [20], [30], [40], [50], [60], [70], [80]])

# Step 3: Normalize data
scaler = MinMaxScaler()
data = scaler.fit_transform(data)

# Step 4: Prepare input and output sequences
X = []
y = []

for i in range(len(data)-2):
    X.append(data[i:i+2])
    y.append(data[i+2])

X = np.array(X)
y = np.array(y)

# Step 5: Build RNN model
model = Sequential()
model.add(SimpleRNN(50, activation='relu', input_shape=(2,1)))
model.add(Dense(1))

# Step 6: Compile model
model.compile(optimizer='adam', loss='mse')

# Step 7: Train model
model.fit(X, y, epochs=200, verbose=1)

# Step 8: Predict
predicted = model.predict(X)
predicted = scaler.inverse_transform(predicted)

print("Predicted values:")
print(predicted)
# Out:
# Epoch 1/200
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.5250
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.4962
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.4681
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.4412
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.4151
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.3908
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.3675
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.3452
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.3238
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.3031
# Epoch 11/200
# ...
